# %% [markdown]
# <a href="https://colab.research.google.com/github/20146174/AI/blob/main/Tuan9(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-fuzzy
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from scikit-fuzzy) (1.22.4)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from scikit-fuzzy) (1.10.1)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from scikit-fuzzy) (3.0)
# Building wheels for collected packages: scikit-fuzzy
#   Building wheel for scikit-fuzzy (setup.py) ... done
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894086 sha256=0fc35115ef5ee21261ae73ade3abe79fcdd387b22d3d0dbbfd13fce285b9334b
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.4.2

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import cifar10
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
import matplotlib.pyplot as plt
img = x_train[30]
plt.imshow(img, cmap = plt.cm.binary)
plt.show
print('so:{}' .format(y_train[30]))
# Out:
# so:[0]

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
from keras import models
from keras.layers import Dense
from keras.models import Sequential

model = Sequential()
model.add(Dense(512,activation='relu', input_shape = (32*32*3,)))
model.add(Dense(256, activation = 'relu'))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((50000, 32*32*3,1))
x_train = x_train.astype('float32')/255
x_test = x_test.reshape((10000, 32*32*3,1))
x_test = x_test.astype('float32')/255

from keras.utils import to_categorical 
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)
     
model.compile(optimizer ='rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train, y_train,epochs = 50, batch_size = 128)
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Do chinh xac tren tap kiem tra', test_acc)
print('Ham mat mat tren tap kiem tra', test_loss)
# Out:
# Epoch 1/50
# 391/391 [==============================] - 13s 32ms/step - loss: 2.1771 - accuracy: 0.1690
# Epoch 2/50
# 391/391 [==============================] - 14s 36ms/step - loss: 1.9760 - accuracy: 0.2664
# Epoch 3/50
# 391/391 [==============================] - 14s 35ms/step - loss: 1.8773 - accuracy: 0.3178
# Epoch 4/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.7981 - accuracy: 0.3476
# Epoch 5/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.7372 - accuracy: 0.3696
# Epoch 6/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.6916 - accuracy: 0.3888
# Epoch 7/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.6548 - accuracy: 0.4036
# Epoch 8/50
# 391/391 [==============================] - 14s 36ms/step - loss: 1.6178 - accuracy: 0.4178
# Epoch 9/50
# 391/391 [==============================] - 14s 36ms/step - loss: 1.5821 - accuracy: 0.4313
# Epoch 10/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.5543 - accuracy: 0.4412
# Epoch 11/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.5278 - accuracy: 0.4520
# Epoch 12/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.5022 - accuracy: 0.4613
# Epoch 13/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4770 - accuracy: 0.4694
# Epoch 14/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4571 - accuracy: 0.4789
# Epoch 15/50
# 391/391 [==============================] - 16s 40ms/step - loss: 1.4346 - accuracy: 0.4854
# Epoch 16/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4160 - accuracy: 0.4930
# Epoch 17/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.3984 - accuracy: 0.4980
# Epoch 18/50
# 391/391 [==============================] - 15s 38ms/step - loss: 1.3797 - accuracy: 0.5054
# Epoch 19/50
# 391/391 [==============================] - 15s 38ms/step - loss: 1.3631 - accuracy: 0.5106
# Epoch 20/50
# 391/391 [==============================] - 14s 35ms/step - loss: 1.3452 - accuracy: 0.5176
# Epoch 21/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.3297 - accuracy: 0.5250
# Epoch 22/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.3094 - accuracy: 0.5316
# Epoch 23/50
# 391/391 [==============================] - 13s 34ms/step - loss: 1.2977 - accuracy: 0.5360
# Epoch 24/50
# 391/391 [==============================] - 14s 35ms/step - loss: 1.2801 - accuracy: 0.5442
# Epoch 25/50
# 391/391 [==============================] - 14s 35ms/step - loss: 1.2656 - accuracy: 0.5496
# Epoch 26/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.2495 - accuracy: 0.5519
# Epoch 27/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.2366 - accuracy: 0.5571
# Epoch 28/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.2189 - accuracy: 0.5648
# Epoch 29/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.2077 - accuracy: 0.5685
# Epoch 30/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.1905 - accuracy: 0.5752
# Epoch 31/50
# 391/391 [==============================] - 14s 36ms/step - loss: 1.1806 - accuracy: 0.5789
# Epoch 32/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.1673 - accuracy: 0.5814
# Epoch 33/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.1546 - accuracy: 0.5869
# Epoch 34/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.1368 - accuracy: 0.5928
# Epoch 35/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.1250 - accuracy: 0.5982
# Epoch 36/50
# 391/391 [==============================] - 13s 34ms/step - loss: 1.1099 - accuracy: 0.6046
# Epoch 37/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.0977 - accuracy: 0.6063
# Epoch 38/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.0848 - accuracy: 0.6124
# Epoch 39/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.0704 - accuracy: 0.6182
# Epoch 40/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.0589 - accuracy: 0.6213
# Epoch 41/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.0469 - accuracy: 0.6257
# Epoch 42/50
# 391/391 [==============================] - 14s 35ms/step - loss: 1.0300 - accuracy: 0.6305
# Epoch 43/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.0202 - accuracy: 0.6360
# Epoch 44/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.0074 - accuracy: 0.6385
# Epoch 45/50
# 391/391 [==============================] - 14s 36ms/step - loss: 0.9943 - accuracy: 0.6454
# Epoch 46/50
# 391/391 [==============================] - 14s 36ms/step - loss: 0.9773 - accuracy: 0.6509
# Epoch 47/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.9658 - accuracy: 0.6551
# Epoch 48/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.9587 - accuracy: 0.6576
# Epoch 49/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.9402 - accuracy: 0.6632
# Epoch 50/50
# 391/391 [==============================] - 17s 44ms/step - loss: 0.9294 - accuracy: 0.6677
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4341 - accuracy: 0.5200
# Do chinh xac tren tap kiem tra 0.5199999809265137
# Ham mat mat tren tap kiem tra 1.4341448545455933

# %%
classes_keys = {0: 'airplane', 1: 'automobile', 2: 'bird',
                3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog',
                7: 'horse', 8: 'ship', 9: 'truck'}
     

from keras.utils import load_img
url = '/content/dog.jpg'
img1 = load_img(url)
plt.imshow(img1)

# %%
from keras.utils import load_img, img_to_array
import numpy as np
img1 = load_img(url, target_size=(32,32))
plt.imshow(img1)

# From image to array to predict
img1 = img_to_array(img1)
img1 = img1.astype('float32')
img1 = img1/255
pred_value = np.argmax(model.predict(img1.reshape(1, 32*32*3), verbose=False),)

# Check the class
for keys in classes_keys.keys():
  if pred_value == keys:
    plt.title(classes_keys[keys])
    break
  else:
    continue
